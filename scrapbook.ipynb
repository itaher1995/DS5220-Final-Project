# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open('train_data.pkl','rb') as f:
    df = pickle.load(f)
df.head(10)
# Out:
#    license                        file_name  \
# 0        5  COCO_train2014_000000200386.jpg
# 1        1  COCO_train2014_000000103817.jpg
# 2        1  COCO_train2014_000000498156.jpg
# 3        1  COCO_train2014_000000563323.jpg
# 4        1  COCO_train2014_000000209229.jpg
# 5        1  COCO_train2014_000000447146.jpg
# 6        1  COCO_train2014_000000215289.jpg
# 7        4  COCO_train2014_000000436981.jpg
# 8        4  COCO_train2014_000000078575.jpg
# 9        6  COCO_train2014_000000550766.jpg
#
#                                             coco_url  height  width  \
# 0  http://images.cocodataset.org/train2014/COCO_t...     640    480
# 1  http://images.cocodataset.org/train2014/COCO_t...     427    640
# 2  http://images.cocodataset.org/train2014/COCO_t...     480    640
# 3  http://images.cocodataset.org/train2014/COCO_t...     640    427
# 4  http://images.cocodataset.org/train2014/COCO_t...     480    640
# ...
